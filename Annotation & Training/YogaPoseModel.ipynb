# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Fri Oct 18 12:16:55 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   60C    P8              14W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !nvidia-smi
# Out:
# Thu Oct 17 18:30:21 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   57C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics==8.0.196
# !pip install albumentations==1.4
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.6/123.6 kB 8.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 1.4.15
#     Uninstalling albumentations-1.4.15:
#       Successfully uninstalled albumentations-1.4.15
# ...

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.2/235.7 GB disk)

# %%
import os
from ultralytics import YOLO
from IPython.display import display, Image

# %%
# %cd /content/drive/MyDrive/AI
# Out:
# /content/drive/MyDrive/AI

# %%
# !ls
# Out:
# AutoAnnotation.ipynb  best_s100.onnx  data.yaml  YogaPoseModel.ipynb  yolov8n.pt
# best_l100.onnx	      Dataset	      runs	 yolov8l-pose.pt      yolov8s-pose.pt

# %%
# %cd /content/drive/MyDrive/AI
from ultralytics import YOLO

# # Load a model
# model = YOLO("yolov8n-pose.yaml")  # build a new model from YAML

# # Train the model
# results = model.train(data="data.yaml", epochs=5, imgsz=640)

# !yolo task=pose mode=train model=yolov8s-pose.pt data=data.yaml epochs=150 imgsz=640 plots=True conf=0.5 batch=16
# Out:
# /content/drive/MyDrive/KMUTT/AI
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py:567: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# !ls runs/pose/train
# Out:
# args.yaml					     labels.jpg        train_batch2.jpg
# BoxF1_curve.png					     PoseF1_curve.png  val_batch0_labels.jpg
# BoxP_curve.png					     PoseP_curve.png   val_batch0_pred.jpg
# BoxPR_curve.png					     PosePR_curve.png  val_batch1_labels.jpg
# BoxR_curve.png					     PoseR_curve.png   val_batch1_pred.jpg
# confusion_matrix_normalized.png			     results.csv       val_batch2_labels.jpg
# confusion_matrix.png				     results.png       val_batch2_pred.jpg
# events.out.tfevents.1728279002.fe07d0aa5f03.14566.0  train_batch0.jpg  weights
# labels_correlogram.jpg				     train_batch1.jpg

# %%
Image(filename='runs/pose/train/confusion_matrix.png', width=600)

# %%
Image(filename='runs/pose/train/val_batch0_pred.jpg', width=1000)

# %%
# !yolo task=pose mode=val model=runs/pose/train/weights/best.pt data=data.yaml

# %%
# !yolo task=pose mode=predict model="/content/best.onnx" conf=0.25 source="/content/aa.jpg"
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.4.0+cpu CPU (Intel Xeon 2.00GHz)
# Loading /content/best.onnx for ONNX Runtime inference...
# requirements: Ultralytics requirements ['onnx', 'onnxruntime'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 306.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 292.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 258.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 299.0 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 5.6s, installed 2 packages: ['onnx', 'onnxruntime']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# image 1/1 /content/aa.jpg: 640x640 1 downdog, 80.9ms
# Speed: 7.0ms preprocess, 80.9ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/pose/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'runs/pose/predict/*.jpg')[:10]:
      display(Image(filename=image_path, width=500))
      print("\n")
