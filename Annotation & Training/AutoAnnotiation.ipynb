# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install mediapipe opencv-python
# Out:
# Requirement already satisfied: mediapipe in /usr/local/lib/python3.10/dist-packages (0.10.15)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (24.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (24.3.25)
# Requirement already satisfied: jax in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.4.33)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.4.33)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mediapipe) (3.7.1)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mediapipe) (4.10.0.84)
# Requirement already satisfied: protobuf<5,>=4.25.3 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (4.25.5)
# Requirement already satisfied: sounddevice>=0.4.4 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (0.4.1)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)

# %%
#2

import cv2
import mediapipe as mp
import os
import random
from shutil import copyfile

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True)  # Use static image mode for processing single images

# Define valid image file extensions
valid_extensions = ('.jpg', '.jpeg', '.png', '.bmp')

# Define a mapping for yoga poses to Class IDs
pose_classes = {
    "aNoPose": 4,

}

# Define the directory paths for images
dataset_path = '/content/drive/MyDrive/KMUTT/AI/onlyNoPose-Dataset'  # Folder containing all pose images
save_dir = '/content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated'  # Base folder to save training, validation, and test datasets

# YOLOv8 keypoint indices based on the mapping from MediaPipe to COCO's 17 keypoints
keypoint_mapping = [
    0,  # Nose
    2,  # Left Eye Inner / Left Eye
    5,  # Right Eye Inner / Right Eye
    7,  # Left Ear
    8,  # Right Ear
    11, # Left Shoulder
    12, # Right Shoulder
    13, # Left Elbow
    14, # Right Elbow
    15, # Left Wrist
    16, # Right Wrist
    23, # Left Hip
    24, # Right Hip
    25, # Left Knee
    26, # Right Knee
    27, # Left Ankle
    28  # Right Ankle
]

# Function to process and save annotations for a given yoga pose
def annotate_pose(image_path, pose_type, save_img_path, save_label_path):
    # Load the image
    image = cv2.imread(image_path)

    if image is None:
        print(f"Failed to load image: {image_path}")
        return

    # Get image dimensions
    img_height, img_width = image.shape[:2]

    # Convert the image to RGB (MediaPipe expects RGB input)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Detect human body pose using MediaPipe
    results = pose.process(image_rgb)

    if not results.pose_landmarks:
        print(f"No pose detected in {image_path}")
        return

    # Retrieve keypoints from the detected pose landmarks (33 keypoints from MediaPipe)
    keypoints = results.pose_landmarks.landmark

    # Map the 33 keypoints to the 17 keypoints for YOLOv8 using the keypoint_mapping
    yolo_keypoints = [keypoints[i] for i in keypoint_mapping]

    # Get x and y coordinates of the selected 17 keypoints
    x_coords = [kp.x for kp in yolo_keypoints]
    y_coords = [kp.y for kp in yolo_keypoints]
    x_min, x_max = min(x_coords), max(x_coords)
    y_min, y_max = min(y_coords), max(y_coords)

    # Calculate the bounding box (center_x, center_y, width, height) and normalize it
    x_center = (x_min + x_max) / 2
    y_center = (y_min + y_max) / 2
    bbox_width = (x_max - x_min)
    bbox_height = (y_max - y_min)

    # Normalize keypoints and add visibility flag using MediaPipe's visibility flag
    normalized_keypoints = []
    for kp in yolo_keypoints:
        kp_x_normalized = kp.x  # Already normalized (relative to image width)
        kp_y_normalized = kp.y  # Already normalized (relative to image height)
        visibility_flag = kp.visibility  # Use MediaPipe's visibility value
        normalized_keypoints.extend([kp_x_normalized, kp_y_normalized, visibility_flag])

    # Get the class ID for the given pose type
    class_id = pose_classes.get(pose_type, -1)
    if class_id == -1:
        print(f"Unknown pose type: {pose_type}")
        return

    # Construct YOLOv8 annotation line (class ID, bbox, and keypoints)
    annotation_line = f"{class_id} {x_center} {y_center} {bbox_width} {bbox_height} " + " ".join(map(str, normalized_keypoints))

    # Save the annotation in YOLOv8 format to a .txt file
    with open(save_label_path, 'w') as f:
        f.write(annotation_line)

    # Save the original image (without drawing pose landmarks)
    copyfile(image_path, save_img_path)
    print(f"Original image saved at {save_img_path} and annotation saved at {save_label_path}")

# Function to split dataset into train, validation, and test sets
def split_dataset(image_paths):
    random.shuffle(image_paths)
    total_images = len(image_paths)

    # Calculate the split sizes
    train_size = int(0.6 * total_images)
    val_size = int(0.2 * total_images)
    test_size = total_images - train_size - val_size

    # Split the dataset
    train_images = image_paths[:train_size]
    val_images = image_paths[train_size:train_size + val_size]
    test_images = image_paths[train_size + val_size:]

    return train_images, val_images, test_images

# Get all image files for each yoga pose
all_images = {
    'aNoPose': [f"{dataset_path}/aNoPose/{img}" for img in os.listdir(f"{dataset_path}/aNoPose") if img.lower().endswith(valid_extensions)],
    # 'easyseat': [f"{dataset_path}/moreeasyseat/{img}" for img in os.listdir(f"{dataset_path}/moreeasyseat") if img.lower().endswith(valid_extensions)],
    # 'tree': [f"{dataset_path}/moretree/{img}" for img in os.listdir(f"{dataset_path}/moretree") if img.lower().endswith(valid_extensions)],
    # 'triangle': [f"{dataset_path}/moretriangle/{img}" for img in os.listdir(f"{dataset_path}/moretriangle") if img.lower().endswith(valid_extensions)],
}

# Define the base directories for images and labels
base_image_dir = os.path.join(save_dir, 'images')
base_label_dir = os.path.join(save_dir, 'labels')

# Create subdirectories for training and validation within the images and labels directories
os.makedirs(os.path.join(base_image_dir, 'train'), exist_ok=True)
os.makedirs(os.path.join(base_image_dir, 'val'), exist_ok=True)
os.makedirs(os.path.join(base_label_dir, 'train'), exist_ok=True)
os.makedirs(os.path.join(base_label_dir, 'val'), exist_ok=True)

# Process each pose type and split the dataset
for pose_type, images in all_images.items():
    # Split dataset
    train_images, val_images, test_images = split_dataset(images)

    # Annotate and save images and labels in train and val sets
    for img_path in train_images:
        img_basename = os.path.basename(img_path)
        save_img_path = os.path.join(base_image_dir, 'train', img_basename)
        save_label_path = os.path.join(base_label_dir, 'train', os.path.splitext(img_basename)[0] + '.txt')
        annotate_pose(img_path, pose_type, save_img_path, save_label_path)

    for img_path in val_images:
        img_basename = os.path.basename(img_path)
        save_img_path = os.path.join(base_image_dir, 'val', img_basename)
        save_label_path = os.path.join(base_label_dir, 'val', os.path.splitext(img_basename)[0] + '.txt')
        annotate_pose(img_path, pose_type, save_img_path, save_label_path)

    # Save only images for the test set, without annotations
    test_image_dir = os.path.join(base_image_dir, 'test')
    os.makedirs(test_image_dir, exist_ok=True)
    for img_path in test_images:
        save_img_path = os.path.join(test_image_dir, os.path.basename(img_path))
        copyfile(img_path, save_img_path)

print("Dataset split complete! Original images saved for training, validation, and test. Annotations saved for training and validation.")
# Out:
# /usr/local/lib/python3.10/dist-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (204).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (204).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (123).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (123).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (27).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (27).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (14).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (14).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (40).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (40).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (44).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (44).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (168).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (168).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (4).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (4).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (219).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (219).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (56).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (56).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (119).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (119).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (209).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (209).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (198).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (198).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (179).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (179).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (162).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (162).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (216).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (216).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (5).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (5).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (49).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (49).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (104).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (104).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (210).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (210).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (176).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (176).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (45).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (45).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (34).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (34).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (17).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (17).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (25).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (25).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (191).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (191).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (10).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (10).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (140).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (140).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (147).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (147).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (41).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (41).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (19).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (19).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (61).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (61).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (72).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (72).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (79).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (79).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (181).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (181).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (21).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (21).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (193).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (193).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (98).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (98).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (218).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (218).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (9).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (9).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (71).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (71).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (102).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (102).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (110).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (110).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (58).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (58).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (28).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (28).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (18).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (18).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (182).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (182).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (129).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (129).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (161).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (161).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (150).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (150).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (115).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (115).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (214).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (214).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (200).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (200).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (217).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (217).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (153).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (153).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (59).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (59).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (171).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (171).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (148).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (148).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (184).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (184).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (157).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (157).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (131).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (131).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (47).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (47).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (69).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (69).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (178).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (178).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (43).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (43).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (22).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (22).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (52).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (52).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (46).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (46).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (15).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (15).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (189).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (189).txt
# No pose detected in /content/drive/MyDrive/KMUTT/AI/onlyNoPose-Dataset/aNoPose/noPos (141).jpg
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (116).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (116).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (195).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (195).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (81).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (81).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (134).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (134).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (50).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (50).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (128).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (128).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (42).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (42).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (66).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (66).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (125).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (125).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (54).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (54).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (151).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (151).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (87).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (87).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (83).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (83).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (78).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (78).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (187).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (187).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (135).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (135).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (160).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (160).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (146).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (146).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (62).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (62).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (199).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (199).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (96).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (96).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (20).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (20).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (3).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (3).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (175).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (175).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (95).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (95).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (91).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (91).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (143).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (143).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (107).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (107).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (205).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (205).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (67).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (67).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (152).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (152).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (31).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (31).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (7).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (7).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (35).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (35).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (32).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (32).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (64).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (64).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (149).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (149).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (55).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (55).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (197).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (197).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (82).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (82).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (97).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (97).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (117).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (117).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (103).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (103).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (121).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (121).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (106).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (106).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (174).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (174).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (48).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (48).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (36).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (36).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (8).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (8).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (84).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (84).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (139).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (139).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (68).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (68).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (159).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (159).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (99).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (99).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (186).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (186).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (113).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (113).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (122).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (122).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (155).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (155).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (39).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (39).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/train/noPos (76).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/train/noPos (76).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (105).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (105).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (80).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (80).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (194).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (194).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (60).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (60).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (57).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (57).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (38).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (38).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (132).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (132).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (89).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (89).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (158).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (158).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (192).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (192).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (211).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (211).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (144).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (144).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (142).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (142).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (112).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (112).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (100).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (100).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (170).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (170).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (213).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (213).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (137).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (137).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (51).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (51).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (180).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (180).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (215).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (215).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (127).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (127).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (145).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (145).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (124).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (124).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (201).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (201).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (70).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (70).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (165).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (165).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (173).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (173).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (12).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (12).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (16).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (16).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (169).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (169).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (92).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (92).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (203).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (203).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (88).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (88).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (108).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (108).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (11).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (11).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (183).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (183).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (163).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (163).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (6).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (6).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (190).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (190).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (86).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (86).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (13).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (13).txt
# Original image saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/images/val/noPos (85).jpg and annotation saved at /content/drive/MyDrive/KMUTT/AI/NoPoseAnnotated/labels/val/noPos (85).txt
# Dataset split complete! Original images saved for training, validation, and test. Annotations saved for training and validation.
